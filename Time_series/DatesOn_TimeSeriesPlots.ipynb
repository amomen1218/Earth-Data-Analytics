# %%
! pip install earthpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 39.8 MB/s eta 0:00:00
# ...

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import pandas as pd
import earthpy as et

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

# %%
precipitation = pd.read_csv('/content/drive/MyDrive/Earth data Analytics/earth-analytics/data/precipitation/805325-precip-dailysum-2003-2013.csv',
                            parse_dates=['DATE'],
                            index_col=['DATE'],
                            na_values=['999.99'])
precipitation.head()
# Out:
# <ipython-input-5-8a66c365e3fd>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   precipitation = pd.read_csv('/content/drive/MyDrive/Earth data Analytics/earth-analytics/data/precipitation/805325-precip-dailysum-2003-2013.csv',
#             DAILY_PRECIP      STATION     STATION_NAME  ELEVATION  LATITUDE  \
# DATE
# 2003-01-01           0.0  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2003-01-05           NaN  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2003-02-01           0.0  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2003-02-02           NaN  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2003-02-03           0.4  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
#
#             LONGITUDE  YEAR  JULIAN
# DATE
# 2003-01-01 -105.28111  2003       1
# 2003-01-05 -105.28111  2003       5
# ...

# %%
# Subset data to June-Aug 2005
precipitation_2005 = precipitation['2005-06-01':'2005-08-31']

precipitation_2005.head()
# Out:
#             DAILY_PRECIP      STATION     STATION_NAME  ELEVATION  LATITUDE  \
# DATE
# 2005-06-01           0.0  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2005-06-02           0.1  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2005-06-03           0.3  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2005-06-04           0.7  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
# 2005-06-09           0.1  COOP:050843  BOULDER 2 CO US     1650.5  40.03389
#
#             LONGITUDE  YEAR  JULIAN
# DATE
# 2005-06-01 -105.28111  2005     152
# 2005-06-02 -105.28111  2005     153
# 2005-06-03 -105.28111  2005     154
# 2005-06-04 -105.28111  2005     155
# 2005-06-09 -105.28111  2005     160

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.bar(precipitation_2005.index.values,
       precipitation_2005['DAILY_PRECIP'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005")

plt.show()

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.bar(precipitation_2005.index.values,
       precipitation_2005['DAILY_PRECIP'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005")

# Define the date format
date_form = DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)

plt.show()

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.bar(precipitation_2005.index.values,
       precipitation_2005['DAILY_PRECIP'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

# Define the date format
date_form = DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)

# Ensure a major tick for each week using (interval=1)
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))

plt.show()
